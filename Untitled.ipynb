# %%
import mc_on_policy as mc
# Out:
# Episode 50000/50000.

# %%
print(len(mc.Q.keys()))
# Out:
# 4520

# %%
import base_agent
import random

from gym_tictactoe.env import TicTacToeEnv, agent_by_mark, check_game_status,\
    after_action_state, tomark, next_mark

# %%
import numpy as np

# %%
def play(max_episode = 10):
    episode = 0
    bs = base_agent.BaseAgent('O')
    env = TicTacToeEnv()
    
    accuracy = 0
    
    while episode < max_episode:
        start_mark = 'O'
        env.set_start_mark('O')
        state = env.reset()
        done = False
        
        iterat = 0
        while not done:
            ava_actions = env.available_actions()
#             print(state[0])
            if iterat%2 == 1:
                
                action = bs.act(state,ava_actions)
                state, reward, done, info = env.step(action)
            else:
#                 probability = mc.policy(state[0])
                print(mc.Q[state[0]])
#                 print(probability)
#                 action = np.random.choice(np.arange(len(probability)),p = probability)
                action = np.argmax(mc.Q[state[0]])
                print(action)
                state,reward,done,_ = env.step(int(action))
            iterat += 1
            env.render()
            accuracy += reward
            start_mark = next_mark(start_mark)
        episode += 1
        
    print(accuracy)

# %%
play(10)
# Out:
# [1.01631399e-05 6.46075681e-06 9.82094536e-06 6.23003271e-06
#  1.37734613e-05 6.50167495e-06 9.93995934e-06 6.61525189e-06
#  1.03247973e-05]
# 4
#    | |
#   -----
#    |O|
#   -----
#    | |
#
#    | |
#   -----
#    |O|
#   -----
#   X| |
#
# [ 0.00200888  0.00133874 -0.0001516   0.00191938  0.          0.00137074
#   0.          0.00130031  0.00215929]
# 8
#    | |
#   -----
#    |O|
#   -----
#   X| |O
#
#    |X|
#   -----
#    |O|
#   -----
#   X| |O
#
# [1.         0.         0.0037     0.0013125  0.         0.00908333
#  0.         0.00263846 0.        ]
# 0
#   O|X|
#   -----
#    |O|
#   -----
#   X| |O
#
# [1.01631399e-05 6.46075681e-06 9.82094536e-06 6.23003271e-06
#  1.37734613e-05 6.50167495e-06 9.93995934e-06 6.61525189e-06
#  1.03247973e-05]
# 4
#    | |
#   -----
#    |O|
#   -----
#    | |
#
#    | |
#   -----
#    |O|
#   -----
#   X| |
#
# [ 0.00200888  0.00133874 -0.0001516   0.00191938  0.          0.00137074
#   0.          0.00130031  0.00215929]
# 8
#    | |
#   -----
#    |O|
#   -----
#   X| |O
#
#    | |X
#   -----
#    |O|
#   -----
#   X| |O
#
# [1.         0.00567857 0.         0.00374375 0.         0.00734167
#  0.         0.00413333 0.        ]
# 0
#   O| |X
#   -----
#    |O|
#   -----
#   X| |O
#
# [1.01631399e-05 6.46075681e-06 9.82094536e-06 6.23003271e-06
#  1.37734613e-05 6.50167495e-06 9.93995934e-06 6.61525189e-06
#  1.03247973e-05]
# 4
#    | |
#   -----
#    |O|
#   -----
#    | |
#
#    | |
#   -----
#    |O|
#   -----
#   X| |
#
# [ 0.00200888  0.00133874 -0.0001516   0.00191938  0.          0.00137074
#   0.          0.00130031  0.00215929]
# 8
#    | |
#   -----
#    |O|
#   -----
#   X| |O
#
#    | |
#   -----
#   X|O|
#   -----
#   X| |O
#
# [ 1.         -0.034      -0.03253333  0.          0.         -0.01440952
#   0.         -0.0036      0.        ]
# 0
#   O| |
#   -----
#   X|O|
#   -----
#   X| |O
#
# [1.01631399e-05 6.46075681e-06 9.82094536e-06 6.23003271e-06
#  1.37734613e-05 6.50167495e-06 9.93995934e-06 6.61525189e-06
#  1.03247973e-05]
# 4
#    | |
#   -----
#    |O|
#   -----
#    | |
#
#    |X|
#   -----
#    |O|
#   -----
#    | |
#
# [ 1.33547059e-03  0.00000000e+00  1.49196629e-03  1.33571739e-03
#   0.00000000e+00  1.76306250e-03  1.57852778e-03 -6.56666667e-05
#   1.32817699e-03]
# 5
#    |X|
#   -----
#    |O|O
#   -----
#    | |
#
#    |X|
#   -----
#    |O|O
#   -----
#   X| |
#
# [0.00373077 0.         0.00558889 1.         0.         0.
#  0.         0.00383529 0.0093125 ]
# 3
#    |X|
#   -----
#   O|O|O
#   -----
#   X| |
#
# [1.01631399e-05 6.46075681e-06 9.82094536e-06 6.23003271e-06
#  1.37734613e-05 6.50167495e-06 9.93995934e-06 6.61525189e-06
#  1.03247973e-05]
# 4
#    | |
#   -----
#    |O|
#   -----
#    | |
#
#    | |
#   -----
#    |O|
#   -----
#    | |X
#
# [-6.43066667e-05  1.26053571e-03  2.15271429e-03  1.50250495e-03
#   0.00000000e+00  1.39215842e-03  1.64240000e-03  1.74134314e-03
#   0.00000000e+00]
# 2
#    | |O
#   -----
#    |O|
#   -----
#    | |X
#
#    | |O
#   -----
#    |O|X
#   -----
#    | |X
#
# [0.00457273 0.01       0.         0.00417857 0.         0.
#  1.         0.00541538 0.        ]
# 6
#    | |O
#   -----
#    |O|X
#   -----
#   O| |X
#
# [1.01631399e-05 6.46075681e-06 9.82094536e-06 6.23003271e-06
#  1.37734613e-05 6.50167495e-06 9.93995934e-06 6.61525189e-06
#  1.03247973e-05]
# 4
#    | |
#   -----
#    |O|
#   -----
#    | |
#
#    |X|
#   -----
#    |O|
#   -----
#    | |
#
# [ 1.33547059e-03  0.00000000e+00  1.49196629e-03  1.33571739e-03
#   0.00000000e+00  1.76306250e-03  1.57852778e-03 -6.56666667e-05
#   1.32817699e-03]
# 5
#    |X|
#   -----
#    |O|O
#   -----
#    | |
#
#    |X|X
#   -----
#    |O|O
#   -----
#    | |
#
# [ 0.00504286  0.          0.          1.          0.          0.
#  -0.02726429 -0.03941667 -0.02279375]
# 3
#    |X|X
#   -----
#   O|O|O
#   -----
#    | |
#
# [1.01631399e-05 6.46075681e-06 9.82094536e-06 6.23003271e-06
#  1.37734613e-05 6.50167495e-06 9.93995934e-06 6.61525189e-06
#  1.03247973e-05]
# 4
#    | |
#   -----
#    |O|
#   -----
#    | |
#
#   X| |
#   -----
#    |O|
#   -----
#    | |
#
# [ 0.          0.00140636  0.00152674  0.00159648  0.          0.0017986
#   0.00178564  0.00134095 -0.00013272]
# 5
#   X| |
#   -----
#    |O|O
#   -----
#    | |
#
#   X| |X
#   -----
#    |O|O
#   -----
#    | |
#
# [ 0.          0.00502     0.          1.          0.          0.
#  -0.03908    -0.0318     -0.05264706]
# 3
#   X| |X
#   -----
#   O|O|O
#   -----
#    | |
#
# [1.01631399e-05 6.46075681e-06 9.82094536e-06 6.23003271e-06
#  1.37734613e-05 6.50167495e-06 9.93995934e-06 6.61525189e-06
#  1.03247973e-05]
# 4
#    | |
#   -----
#    |O|
#   -----
#    | |
#
#    | |
#   -----
#   X|O|
#   -----
#    | |
#
# [ 1.95589899e-03  1.66258416e-03  1.91364423e-03  0.00000000e+00
#   0.00000000e+00 -1.01747573e-05  1.79769072e-03  1.62438043e-03
#   1.38881000e-03]
# 0
#   O| |
#   -----
#   X|O|
#   -----
#    | |
#
#   O|X|
#   -----
#   X|O|
#   -----
#    | |
#
# [0.         0.         0.00440625 0.         0.         0.00403
#  0.00254375 0.00254167 1.        ]
# 8
#   O|X|
#   -----
#   X|O|
#   -----
#    | |O
#
# [1.01631399e-05 6.46075681e-06 9.82094536e-06 6.23003271e-06
#  1.37734613e-05 6.50167495e-06 9.93995934e-06 6.61525189e-06
#  1.03247973e-05]
# 4
#    | |
#   -----
#    |O|
#   -----
#    | |
#
#    | |
#   -----
#    |O|
#   -----
#    | |X
#
# [-6.43066667e-05  1.26053571e-03  2.15271429e-03  1.50250495e-03
#   0.00000000e+00  1.39215842e-03  1.64240000e-03  1.74134314e-03
#   0.00000000e+00]
# 2
#    | |O
#   -----
#    |O|
#   -----
#    | |X
#
#    |X|O
#   -----
#    |O|
#   -----
#    | |X
#
# [1.37272727e-03 0.00000000e+00 0.00000000e+00 4.28181818e-03
#  0.00000000e+00 6.69166667e-03 1.00000000e+00 6.29411765e-04
#  0.00000000e+00]
# 6
#    |X|O
#   -----
#    |O|
#   -----
#   O| |X
#
# [1.01631399e-05 6.46075681e-06 9.82094536e-06 6.23003271e-06
#  1.37734613e-05 6.50167495e-06 9.93995934e-06 6.61525189e-06
#  1.03247973e-05]
# 4
#    | |
#   -----
#    |O|
#   -----
#    | |
#
#    |X|
#   -----
#    |O|
#   -----
#    | |
#
# [ 1.33547059e-03  0.00000000e+00  1.49196629e-03  1.33571739e-03
#   0.00000000e+00  1.76306250e-03  1.57852778e-03 -6.56666667e-05
#   1.32817699e-03]
# 5
#    |X|
#   -----
#    |O|O
#   -----
#    | |
#
#   X|X|
#   -----
#    |O|O
#   -----
#    | |
#
# [ 0.          0.          0.00923846  1.          0.          0.
#  -0.02526471 -0.0274     -0.0197    ]
# 3
#   X|X|
#   -----
#   O|O|O
#   -----
#    | |
#
# 10
